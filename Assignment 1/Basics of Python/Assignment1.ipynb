# %% [markdown]
# Coding Exercises

# %%
### Exercise 1: Prime Numbers
### Write a Python program that checks whether a given number is prime or not

# %%
n=int(input("Enter the number"))
if n<=1:
  print(n ,":is not a prime number")
else:
  for i in range(2,n):
   if n%i==0:
    print(n ,":is not a prime number")
    break
  else:
   print(n,": is prime number")
# Out:
# Enter the number 37
# 37 : is prime number

# %%
## Exercise 2: Product of Random Numbers
##Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. 
##The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
num1= random.randint(1,10)
num2= random.randint(1,10)
print("num1:",num1,",","num2:",num2)
num3=int(input("Enter the product of the numbers :"))
if num3 == num1*num2:
    print("Well done,Correct answer")
else:
    print("Incorrect answer")
    print("Correct answer is:", num1*num2)
# Out:
# num1: 5 , num2: 7
# Enter the product of the numbers : 30
# Incorrect answer
# Correct answer is: 35

# %%
##3Exercise 3: Squares of Even Numbers
## Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. 
##Choose either even or odd numbers and document your choice in the code.

# %%
#Squares of Even Numbers 
for n in range(100,201):
 if n%2==0: #check if the number is even
  print("square of", n,":",n**2)
# Out:
# square of 100 : 10000
# square of 102 : 10404
# square of 104 : 10816
# square of 106 : 11236
# square of 108 : 11664
# square of 110 : 12100
# square of 112 : 12544
# square of 114 : 12996
# square of 116 : 13456
# square of 118 : 13924
# square of 120 : 14400
# square of 122 : 14884
# square of 124 : 15376
# square of 126 : 15876
# square of 128 : 16384
# square of 130 : 16900
# square of 132 : 17424
# square of 134 : 17956
# square of 136 : 18496
# square of 138 : 19044
# square of 140 : 19600
# square of 142 : 20164
# square of 144 : 20736
# square of 146 : 21316
# square of 148 : 21904
# square of 150 : 22500
# square of 152 : 23104
# square of 154 : 23716
# square of 156 : 24336
# square of 158 : 24964
# square of 160 : 25600
# square of 162 : 26244
# square of 164 : 26896
# square of 166 : 27556
# square of 168 : 28224
# square of 170 : 28900
# square of 172 : 29584
# square of 174 : 30276
# square of 176 : 30976
# square of 178 : 31684
# square of 180 : 32400
# ...

# %%
#Exercise 4:Problem Statement (Question): Hospital Billing System
#A hospital charges its patients based on the following:
#	Room charges per day: ₹2,000
#	Doctor consultation fee (flat): ₹1,500
#	Lab test charges: Based on the number of tests taken. Each test costs ₹300
#	Medicine charges: Total cost of medicines provided
#	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
#Write a Python program to calculate the final bill for a patient who:
#	Stayed for 4 days

# %%
### Fixed charges
room_charges_perday = 2000
doctor_fee= 1500

#Patient details
days_stayed=4
lab_test=int(input("Enter the number of lab tests"))
medicine_charges=float(input("Enter the medicine cost"))

#Calculations
room_charges=room_charges_perday * days_stayed
lab_charges=lab_test * 300
Total_bill= doctor_fee + room_charges + lab_charges + medicine_charges


# Discount
if Total_bill > 10000:
    discount = 0.10 * Total_bill
else:
    discount = 0

final_bill = Total_bill - discount

print("Hospital Bill Summary")
print("Doctor Fees:",doctor_fee)
print("Room charges:",room_charges)
print("Lab test charges:",lab_charges)
print("Cost of medicines:",medicine_charges)
print("Total Bill is:",Total_bill)
print("Discount:",discount)
print("Final Bill is:",final_bill)
# Out:
# Enter the number of lab tests 3
# Enter the medicine cost 5000
# Hospital Bill Summary
# Doctor Fees: 1500
# Room charges: 8000
# Lab test charges: 900
# Cost of medicines: 5000.0
# Total Bill is: 15400.0
# Discount: 1540.0
# Final Bill is: 13860.0
